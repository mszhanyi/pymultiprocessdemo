# %%
from multiprocessing import Pool
from mpfunc import *

# %%
# see the current main module
print(sys.modules["__main__"].__dict__)
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'from multiprocessing import Pool\nfrom mpfunc import *', '# see the current main module\nprint(sys.modules["__main__"].__dict__)'], '_oh': {}, '_dh': ['d:\\git\\zyrepo\\pymultiprocessdemo\\demos'], 'In': ['', 'from multiprocessing import Pool\nfrom mpfunc import *', '# see the current main module\nprint(sys.modules["__main__"].__dict__)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000015A01CB7460>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000015A01CED4C0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000015A01CED4C0>, '_': '', '__': '', '___': '', '_i': 'from multiprocessing import Pool\nfrom mpfunc im
# ...

# %%
# start child process and print the main module info in the child process
with Pool(2) as p:
    print(p.map(get_subproc_info, [1, 2, 3]))
# Out:
# [19632, 20788, 19632]

# %% [markdown]
# On Windows, from the jupyter command window, we can find that subprocess main module doesn't copy complete context of parent process.
# ![image.png](attachment:image.png)

# %% [markdown]
# If we define one function in the same notebook and run it parallely, Notebook will hang. Because this function isn't copied to the child process.

# %%
def f(x):
    return x*x

# %%
# After running the below cell, you need to restart the while notebook

# %%
with Pool(2) as p:
    print(p.map(f, [1, 2, 3]))
